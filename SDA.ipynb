# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunrawal21/Afame-Technologies/blob/main/SDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Import Dataset**

# %%
SD = pd.read_excel("/content/ECOMM DATA.xlsx")
SD
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %% [markdown]
# **EDA ON Dataset**

# %%
SD.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
SD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
SD.nunique()
# Out:
# Row ID            51290
# Order ID          25035
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID        1590
# Customer Name       795
# Segment               3
# City               3636
# State              1094
# Country             147
# Postal Code         631
# Market                7
# Region               13
# Product ID        10292
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             24988
# Quantity             14
# Discount             27
# Profit            27085
# Shipping Cost     16936
# Order Priority        4
# dtype: int64

# %%
SD.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %% [markdown]
# **Checking Null Values**

# %%
SD.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
SD.drop('Postal Code', axis = 1)
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
Total_sales = SD['Sales'].sum()
Total_sales
# Out:
# 12642501.909880001

# %% [markdown]
# **`Sales By Category`**

# %%
Sales_per_category = SD.groupby('Category')['Sales'].sum()
plt.figure(figsize=(8,3))
sns.barplot(x=Sales_per_category.index, y=Sales_per_category.values)
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.title('Sales per Category')
# Out:
# Text(0.5, 1.0, 'Sales per Category')

# %% [markdown]
# **sales Trend over the time**

# %%
SD['Year'] = pd.to_datetime(SD['Order Date']).dt.year

# %%
sales_trends_by_year = SD.groupby('Year')['Sales'].sum()
plt.figure(figsize=(8,3))
sns.barplot(x=sales_trends_by_year.index, y=sales_trends_by_year.values)
plt.title('Sales Trends by Year with')
plt.xlabel('Year')
plt.ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# **Sales Trend by months Of Each Year**

# %%
SD['Month'] = pd.to_datetime(SD['Order Date']).dt.month

# %%
sales_trends_by_month_year = SD.groupby(['Year', 'Month'])['Sales'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='Sales', hue='Year', data=sales_trends_by_month_year)
plt.title('Sales Trend by Month of Each Year')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(range(1, 13))
plt.legend(title='Year')
plt.show()

# %% [markdown]
#  **Top 3 best selling Product**

# %%
Top_3_best_selling_product = SD.groupby('Product Name')['Sales'].sum().nlargest(3)
plt.figure(figsize=(10,3))
plt.bar(Top_3_best_selling_product.index, Top_3_best_selling_product.values)
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.title('Top 3 best selling Product')
plt.show()

# %% [markdown]
# # ***Summary ***
#
# **In this project, I conducted an in-depth analysis of sales data to uncover
# trends and insights. The analysis focused on three product categories:**
#
# Furniture, Technology, and Office Supplies. Technology products emerged as the highest-selling category, outperforming Furniture and Office Supplies.**
#
# I also examined sales trends from 2011 to 2014, revealing a consistent year-over-year increase, with 2014 recording the highest overall sales. Monthly analysis showed November 2014 as the peak month for sales, indicating a strong seasonal trend.
#
# Additionally, I identified the top three best-selling products: Apple led the list, followed by Cisco phones and Motorola smartphones. These insights provide actionable information for strategic decision-making, including category-specific investment, seasonal promotions, and sales forecasting.
